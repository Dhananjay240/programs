# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhananjay240/programs/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
data = pd.read_csv('wholesale.csv')
data
np.amax(data)
np.amin(data)
import seaborn as sns
data1 = pd.read_csv('wholesale.csv', skiprows=1,usecols=[3])
data1
np.mean(data1)
iqr = np.percentile(data1,75) - np.percentile(data1,25)
iqr
np.sort(data1,axis=1)
iqr = np.percentile(data1,75) - np.percentile(data1,25)
iqr
# Out:
# 13815.0

# %%
lower_b = np.percentile(data1,25)
lower_b*1.5
# Out:
# 4679.25

# %%
upper_b = np.percentile(data1,75)
upper_b*1.5
# Out:
# 25401.75

# %%
ax = sns.boxplot(x = 'Buyer/Spender',y = 'Fresh',data = data)

# %%
## correlation matrix 
## I did it in deep learning course
import matplotlib.pyplot as plt
plt.plot(data1)
plt.show()
correlation = data1.corr()
sns.heatmap(data1)
